# %%
import matplotlib.pylab as plt
import numpy as np
from IPython.display import clear_output

# %%
# %%bash
# c++ bifurcacion.cpp -o bi.x
# ./bi.x 1000 > bi.dat

# %%
data = np.loadtxt("bi.dat")
y = data[:,0]
x =data[:,1]

plt.figure(figsize=(12,10)),
plt.plot(x,y,".")
plt.xlabel("Fuerza")
plt.ylabel('$\\Theta$')
plt.title('Bifurcacion')
plt.grid()
plt.savefig("bifurcacion.png")
