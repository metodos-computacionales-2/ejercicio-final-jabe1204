# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
# %%bash
# g++ pendulum.cpp
# ./a.out 10000000 > data.txt

# %%
datos = np.loadtxt("data.txt")
t = datos[:,0]
theta = datos[:,1]
omega = datos[:,2]
plt.plot(t[:100],theta[:100])
plt.xlabel('t')
plt.ylabel('$\Theta$')
plt.savefig ('angulovst.png')
